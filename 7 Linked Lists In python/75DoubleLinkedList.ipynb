# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None

# %%
class DoubleLinkedList:
    def __init__(self):
        self.head = None

# %%
def deletebegin(self):
    if self.head == None:
        print("Empty Linked List")
        return
    self.head = self.head.next
    self.head.prev = None

def deleteend(self):
    if self.head == None:
        print("Empty Linked List")
        return
    n = self.head
    previous = None
    while n.next is not None:
        previous = n
        n = n.next
    previous.next = None
    n.prev = None

def deletevalue(self,x):
    if self.head == None:
        print("Empty Linked List")
        return
    n = self.head
    previous = None
    while n is not None:
        if n.data == x: break
        previous = n
        n = n.next
    if n.data == x: 
        previous.next = n.next
        n.next.prev = n.prev
    else: print("Value Not Found In Linked List")

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None

class DoubleLinkedList:
    def __init__(self):
        self.head = None

    def emptylst(self,data):
        if self.head is None: 
            newnode = Node(data)
            self.head = newnode
        else: print("Linked List Is not empty")

    def insertbeg(self,data):
        if self.head is None:
            newnode = Node(data)
            self.head = newnode
        else:
            newnode = Node(data)
            newnode.next = self.head
            self.head.prev = newnode
            self.head = newnode

    def insertend(self,data):
        if self.head is None:
            newnode = Node(data)
            self.head = newnode
        else:
            n = self.head
            while n.next is not None:
                n = n.next
            newnode = Node(data)
            n.next = newnode
            newnode.prev = n

    def insertafter(self,data,x):
        if self.head is None:
            print("Empty Linked List")
            return
        n = self.head
        while n.next is not None:
            if n.data == x: break
            n = n.next
        if n.data == x:
            newnode = Node(data)
            newnode.next = n.next
            newnode.prev = n
            n.next.prev = newnode
            n.next = newnode
        else:
            print("Value Not Present Linked List")
            return

    def insertbefore(self,data,x):
        if self.head is None:
            print("Empty Linked List")
            return
        if self.head.data == x:
            newnode = Node(data)
            newnode.next = self.head
            self.head.prev = newnode
            self.head = newnode
            return
        n = self.head
        previous = None
        while n.next is not None:
            if n.data == x: break
            previous = n
            n = n.next
        if n.data == x:
            newnode = Node(data)
            newnode.next = previous.next
            newnode.prev = n.prev
            previous.next = newnode
            n.prev = newnode
        else:
            return "Value Not Present In Linked List"

    def deletebegin(self):
        if self.head == None:
            print("Empty Linked List")
            return
        self.head = self.head.next
        self.head.prev = None

    def deleteend(self):
        if self.head == None:
            print("Empty Linked List")
            return
        n = self.head
        previous = None
        while n.next is not None:
            previous = n
            n = n.next
        previous.next = None
        n.prev = None

    def deletevalue(self,x):
        if self.head == None:
            print("Empty Linked List")
            return
        n = self.head
        previous = None
        while n is not None:
            if n.data == x: break
            previous = n
            n = n.next
        if n.data == x: 
            previous.next = n.next
            n.next.prev = n.prev
        else: print("Value Not Found In Linked List")

    def printList(self):
        n = self.head
        if self.head is None:
            print("Empty Linked List")
            return
        while n is not None:
            print(n.data,end = '<==>')
            n = n.next
        print()

    def printListReverse(self):
        n = self.head
        if self.head is None:
            print("Empty Linked List")
            return
        while n.next is not None:
            n = n.next
        while n is not None:
            print(n.data,end = '<==>')
            n = n.prev
        print()
    
if __name__ == '__main__':
    lst1 = DoubleLinkedList()
    lst1.emptylst(20)
    lst1.insertbeg(10)
    lst1.insertend(50)
    lst1.insertbefore(40,50)
    lst1.insertafter(30,20)
    lst1.deletebegin()
    lst1.deleteend()
    lst1.deletevalue(30)
    lst1.printList()
    lst1.printListReverse()
