# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None

# %%
class DoubleCircularLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

# %%
def emptylst(self,data):
    if self.head is None: 
        newnode = Node(data)
        self.head = newnode
        self.tail = newnode
        newnode.next = self.head
    else: print("Linked List Is not empty")

def insertbeg(self,data):
    if self.head is None:
        newnode = Node(data)
        self.head = newnode
        self.tail = newnode
        newnode.next = self.head    
    else:
        newnode = Node(data)
        newnode.next = self.head
        self.head.prev = newnode
        self.head = newnode
        newnode.prev = self.tail
        self.tail.next = self.head

def insertend(self,data):
    if self.head is None:
        newnode = Node(data)
        self.head = newnode
        self.tail = newnode
        newnode.next = self.head
    else:
        newnode = Node(data)
        self.tail.next = newnode
        newnode.prev = self.tail
        newnode.next = self.head
        self.tail = newnode 

def insertafter(self,data,x):
    if self.head is None:
        print("Empty Linked List")
        return
    n = self.head
    while n.next is not self.head:
        if n.data == x: break
        n = n.next
    if n.data == x:
        newnode = Node(data)
        newnode.next = n.next
        newnode.prev = n
        n.next.prev = newnode
        n.next = newnode
    else:
        print("Value Not Present Linked List")
        return

def insertbefore(self,data,x):
    if self.head is None:
        print("Empty Linked List")
        return
    if self.head.data == x:
        newnode = Node(data)
        self.head = newnode
        self.tail = newnode
        newnode.next = self.head
        return
    n = self.head
    previous = None
    while n.next is not self.head:
        if n.data == x: break
        previous = n
        n = n.next
    if n.data == x:
        newnode = Node(data)
        newnode.next = previous.next
        newnode.prev = n.prev
        previous.next = newnode
        n.prev = newnode
    else:
        return "Value Not Present In Linked List"

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None

class DoubleCircularLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def emptylst(self,data):
        if self.head is None: 
            newnode = Node(data)
            self.head = newnode
            self.tail = newnode
            newnode.next = self.head
        else: print("Linked List Is not empty")

    def insertbeg(self,data):
        if self.head is None:
            newnode = Node(data)
            self.head = newnode
            self.tail = newnode
            newnode.next = self.head    
        else:
            newnode = Node(data)
            newnode.next = self.head
            self.head.prev = newnode
            self.head = newnode
            newnode.prev = self.tail
            self.tail.next = self.head

    def insertend(self,data):
        if self.head is None:
            newnode = Node(data)
            self.head = newnode
            self.tail = newnode
            newnode.next = self.head
        else:
            newnode = Node(data)
            self.tail.next = newnode
            newnode.prev = self.tail
            newnode.next = self.head
            self.tail = newnode 

    def insertafter(self,data,x):
        if self.head is None:
            print("Empty Linked List")
            return
        n = self.head
        while n.next is not self.head:
            if n.data == x: break
            n = n.next
        if n.data == x:
            newnode = Node(data)
            newnode.next = n.next
            newnode.prev = n
            n.next.prev = newnode
            n.next = newnode
        else:
            print("Value Not Present Linked List")
            return

    def insertbefore(self,data,x):
        if self.head is None:
            print("Empty Linked List")
            return
        if self.head.data == x:
            newnode = Node(data)
            self.head = newnode
            self.tail = newnode
            newnode.next = self.head
            return
        n = self.head
        previous = None
        while n.next is not self.head:
            if n.data == x: break
            previous = n
            n = n.next
        if n.data == x:
            newnode = Node(data)
            newnode.next = previous.next
            newnode.prev = n.prev
            previous.next = newnode
            n.prev = newnode
        else:
            return "Value Not Present In Linked List"

    def printList(self):
        n = self.head
        if self.head is None:
            print("Empty Linked List")
            return
        while n.next is not self.head:
            print(n.data,end = '<==>')
            n = n.next
        print(n.data)
        print()

    def printListReverse(self):
        n = self.head
        if self.head is None:
            print("Empty Linked List")
            return
        n = self.tail
        while n.prev is not self.tail:
            print(n.data,end = '<==>')
            n = n.prev
        print(n.data)
        print()
    
if __name__ == '__main__':
    lst1 = DoubleCircularLinkedList()
    lst1.emptylst(20)
    lst1.insertbeg(10)
    lst1.insertbeg(30)
    lst1.insertbeg(40)            # There is error we will sort later
    lst1.insertbeg(50)
    # lst1.insertbefore(40,50)
    # lst1.insertafter(30,20)
    lst1.printList()
    lst1.printListReverse()
